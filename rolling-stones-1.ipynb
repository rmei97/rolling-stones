# %%
import csv
from collections import OrderedDict
import math

dict_data = []
with open('data.csv') as f:
    reader = csv.DictReader(f)
    for row in reader:
        dict_data.append(row)

# %%
print(dict_data)
    
# data_dict = {'number': data[0],
#              'year' : data[1],
#              'album' : data[2],
#              'artist' : data[3],
#              'genre' : data[4]
#             }
# Out:
# [OrderedDict([('number', '1'), ('year', '1967'), ('album', "Sgt. Pepper's Lonely Hearts Club Band"), ('artist', 'The Beatles'), ('genre', 'Rock'), ('subgenre', 'Rock & Roll, Psychedelic Rock')]), OrderedDict([('number', '2'), ('year', '1966'), ('album', 'Pet Sounds'), ('artist', 'The Beach Boys'), ('genre', 'Rock'), ('subgenre', 'Pop Rock, Psychedelic Rock')]), OrderedDict([('number', '3'), ('year', '1966'), ('album', 'Revolver'), ('artist', 'The Beatles'), ('genre', 'Rock'), ('subgenre', 'Psychedelic Rock, Pop Rock')]), OrderedDict([('number', '4'), ('year', '1965'), ('album', 'Highway 61 Revisited'), ('artist', 'Bob Dylan'), ('genre', 'Rock'), ('subgenre', 'Folk Rock, Blues Rock')]), OrderedDict([('number', '5'), ('year', '1965'), ('album', 'Rubber Soul'), ('artist', 'The Beatles'), ('genre', 'Rock, Pop'), ('subgenre', 'Pop Rock')]), OrderedDict([('number', '6'), ('year', '1971'), ('album', "What's Going On"), ('artist', 'Marvin Gaye'), ('genre', 'Funk / Soul'), ('subgenre', 'Soul')]), OrderedDict([('number', '7'), ('year', '1972'), ('album', 'Exile on Main St.'), ('artist', 'The Rolling Stones'), ('genre', 'Rock'), ('subgenre', 'Blues Rock, Rock & Roll, Classic Rock')]), OrderedDict([('number', '8'), ('year', '1979'), ('album', 'London Calling'), ('artist', 'The Clash'), ('genre', 'Rock'), ('subgenre', 'Punk, New Wave')]), OrderedDict([('number', '9'), ('year', '1966'), ('album', 'Blonde on Blonde'), ('artist', 'Bob Dylan'), ('genre', 'Rock, Blues'), ('subgenre', 'Folk Rock, Rhythm & Blues')]), OrderedDict([('number', '10'), ('year', '1968'), ('album', 'The Beatles ("The White Album")'), ('artist', 'The Beatles'), ('genre', 'Rock'), ('subgenre', 'Rock & Roll, Pop Rock, Psychedelic Rock, Experimental')]), OrderedDict([('number', '11'), ('year', '1976'), ('album', 'The Sun Sessions'), ('artist', 'Elvis Presley'), ('genre', 'Rock'), ('subgenre', 'Rock & Roll')]), OrderedDict([('number', '12'), ('year', '1959'), ('album', 'Kind of Blue'), ('artist', 'Miles Davis'), ('genre', 'Jazz'), ('subgenre', 'Modal')]), OrderedDict([('number', '13'), ('year', '1967'), ('album', 'The Velvet Underground & Nico'), ('artist', 'The Velvet Underground'), ('genre', 'Rock'), ('subgenre', 'Garage Rock, Art Rock, Experimental')]), OrderedDict([('number', '14'), ('year', '1969'), ('album', 'Abbey Road'), ('artist', 'The Beatles'), ('genre', 'Rock'), ('subgenre', 'Psychedelic Rock, Classic Rock, Pop Rock')]), OrderedDict([('number', '15'), ('year', '1967'), ('album', 'Are You Experienced'), ('artist', 'The Jimi Hendrix Experience'), ('genre', 'Rock, Blues'), ('subgenre', 'Blues Rock, Psychedelic Rock')]), OrderedDict([('number', '16'), ('year', '1975'), ('album', 'Blood on the Tracks'), ('artist', 'Bob Dylan'), ('genre', 'Rock'), ('subgenre', 'Folk Rock, Acoustic, Ballad')]), OrderedDict([('number', '17'), ('year', '1991'), ('album', 'Nevermind'), ('artist', 'Nirvana'), ('genre', 'Rock'), ('subgenre', 'Alternative Rock, Grunge')]), OrderedDict([('number', '18'), ('year', '1975'), ('album', 'Born to Run'), ('artist', 'Bruce Springsteen'), ('genre', 'Rock'), ('subgenre', 'Pop Rock')]), OrderedDict([('number', '19'), ('year', '1968'), ('album', 'Astral Weeks'), ('artist', 'Van Morrison'), ('genre', 'Jazz, Rock, Blues, Folk, World, & Country'), ('subgenre', 'Acoustic, Classic Rock, Free Improvisation')]), OrderedDict([('number', '20'), ('year', '1982'), ('album', 'Thriller'), ('artist', 'Michael Jackson'), ('genre', 'Funk / Soul, Pop'), ('subgenre', 'Disco')]), OrderedDict([('number', '21'), ('year', '1982'), ('album', 'The Great Twenty Eight'), ('artist', 'Chuck Berry'), ('genre', 'Rock'), ('subgenre', 'Rock & Roll')]), OrderedDict([('number', '22'), ('year', '1990'), ('album', 'The Complete Recordings'), ('artist', 'Robert Johnson'), ('genre', 'Blues'), ('subgenre', 'Delta Blues')]), OrderedDict([('number', '23'), ('year', '1970'), ('album', 'John Lennon/Plastic Ono Band'), ('artist', 'John Lennon / Plastic Ono Band'), ('genre', 'Rock'), ('subgenre', 'P ...

# %%
def find_by_name(album):
    # find someting in the reader
    for item in dict_data:
        x = collections.OrderedDict(item)
            # makes it all CAPS to compare
        if x['album'].upper() == album.upper():
            return x
        else:
            continue
    print("Not in the list")

    
find_by_name('London calling')
# Out:
# OrderedDict([('number', '8'),
#              ('year', '1979'),
#              ('album', 'London Calling'),
#              ('artist', 'The Clash'),
#              ('genre', 'Rock'),
#              ('subgenre', 'Punk, New Wave')])

# %%
def find_by_rank(rank):
    for item in dict_data:
        x = collections.OrderedDict(item)
        if int(x['number']) == rank:
            return x
        else:
            continue
    print("This is not ranked")

# %%
find_by_rank(5000)
# Out:
# This is not ranked

# %%
x = collections.OrderedDict([('number', '8'),
             ('year', '1979'),
             ('album', 'London Calling'),
             ('artist', 'The Clash'),
             ('genre', 'Rock'),
             ('subgenre', 'Punk, New Wave')])

# %%
x['year']
# Out:
# '1979'
